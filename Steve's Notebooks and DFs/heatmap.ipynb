# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('final_df.csv', index_col = 0)

# %%
df_corr = df.corr()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df_corr, linewidths=.05, cmap = 'Blues')
plt.savefig('heatmap.png')
plt.show()

# %%
df_corr[['total_cost','monthly_passengers', 'monthly_mail']]
# Out:
#                     total_cost  monthly_passengers  monthly_mail
# origin_airport_id    -0.039664           -0.021656     -0.030774
# dest_airport_id      -0.040065           -0.021873     -0.031247
# taxi_out             -0.121941           -0.188590      0.017044
# taxi_in              -0.041080           -0.107058      0.061782
# distance              0.283415            0.213320      0.289062
# dep_hour             -0.008213           -0.003565     -0.014305
# arr_hour              0.023954            0.027386      0.015173
# perc_del             -0.608684           -0.669698     -0.306250
# med_dep_delay         0.414632            0.690707     -0.039230
# med_arr_delay        -0.449064           -0.405971     -0.276385
# med_distance          0.561579            0.432156      0.568820
# mean_carr            -0.256692           -0.307384     -0.154436
# mean_weather         -0.405411           -0.457997     -0.190641
# mean_nas              0.010449           -0.230127      0.284114
# mean_sec              0.030686            0.385435     -0.367363
# mean_late_air        -0.618124           -0.643829     -0.385541
# total_cost            1.000000            0.901436      0.837643
# monthly_passengers    0.901436            1.000000      0.542321
# monthly_mail          0.837643            0.542321      1.000000
# dep_fl_lv             0.156152            0.070320      0.228165
# dep_fl_ar             0.157897            0.089028      0.202160
# arr_fl_lv             0.155942            0.090047      0.197419
# arr_fl_ar             0.158881            0.080829      0.219278
# dep_ps_tt             0.224493            0.138347      0.262328
# arr_ps_tt             0.226806            0.142556      0.261827

# %%
df = df.drop(['origin', 'dest'], axis = 1)

# %%
df = pd.get_dummies(df, columns =['op_unique_carrier'])

# %%
df.to_csv('Final_dummies.csv')
