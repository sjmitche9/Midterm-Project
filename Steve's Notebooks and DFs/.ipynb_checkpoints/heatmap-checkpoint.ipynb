# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('final_df.csv')

# %%
df_corr = df.corr()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df_corr, linewidths=.05)
plt.show()
